# %% [markdown]
# <a href="https://colab.research.google.com/github/williamtatecarr/DS-1002/blob/main/Assignments/06_Pandas_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pandas exercises 1
#
# 1. Import dependencies

# %%
import seaborn as sns

import pandas as pd

# %% [markdown]
# ---

# %%
list = [98, 24, 46, 87, 33]

# %% [markdown]
# 2. Convert `list` to a pandas series using `pd.Series`

# %%
ps = pd.Series(list)

# %% [markdown]
# 3. Take the above series and add an index that starts at 2 and steps by 3

# %%
ps.index = range(2, 2 + len(ps)*3, 3)
ps
# Out:
# 2     98
# 5     24
# 8     46
# 11    87
# 14    33
# dtype: int64

# %% [markdown]
# 4. Create a dictionary of 4 names, ages, and careers
# Convert this dictionary to a pandas dataframe: `df`.
# Print the dataframe.

# %%
df = pd.DataFrame({'names': ['Jim','Ryan', 'Abraham','Adam'],
             'ages': [26, 56, 28, 40],
             'careers': ['Data Scientist', 'Professor ', 'Investment Banker', 'Nurse']})


print(df)
# Out:
#      names  ages            careers
# 0      Jim    26     Data Scientist
# 1     Ryan    56         Professor
# 2  Abraham    28  Investment Banker
# 3     Adam    40              Nurse

# %% [markdown]
# 5. Name the index of `df` 'participant_id'.
# Print `df`.

# %%
df.index.name = 'particpant_id'
print(df)
# Out:
#                  names  ages            careers
# particpant_id
# 0                  Jim    26     Data Scientist
# 1                 Ryan    56         Professor
# 2              Abraham    28  Investment Banker
# 3                 Adam    40              Nurse

# %% [markdown]
# 6. Use a pandas function to determine the data types of the columns of `df`.

# %%
df.dtypes
# Out:
# names      object
# ages        int64
# careers    object
# dtype: object

# %% [markdown]
# 7. Using bracket notation, reference column `name`

# %%
df['names']
# Out:
# particpant_id
# 0        Jim
# 1       Ryan
# 2    Abraham
# 3       Adam
# Name: names, dtype: object

# %% [markdown]
# 8. Using dot notation, reference column `name`

# %%
df.names
# Out:
# particpant_id
# 0        Jim
# 1       Ryan
# 2    Abraham
# 3       Adam
# Name: names, dtype: object

# %% [markdown]
# 8. Reference column `name` and have it returned in a dataframe.

# %%
 df1=pd.DataFrame(df.names)
 #type(df1) to check if its dataframe
df1
# Out:
#                  names
# particpant_id
# 0                  Jim
# 1                 Ryan
# 2              Abraham
# 3                 Adam

# %% [markdown]
# 9. Show the 3rd element in column `career`.

# %%
df['names'][3]
# Out:
# 'Adam'

# %% [markdown]
# 10.  Load the `iris` dataset that we used in class.  Use `iris` as the name of your data frame.

# %%
import seaborn as sns
iris = sns.load_dataset('iris')
#type(iris) : already a data frame
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# 11.  What is the correlation between the variables `sepal_length` and `sepal_width` for all the irises?

# %%
iris[['sepal_length','petal_length']].corr()
# Out:
#               sepal_length  petal_length
# sepal_length      1.000000      0.871754
# petal_length      0.871754      1.000000

# %% [markdown]
# 12.  Which of the three species has the highest correlation between `sepal_length` and `sepal_width`?  Show any calculations you use to support your answer.

# %%
#iris2 = iris.sort_values(by=['species']) to sort by species name for clarity, but only shows first and last rows
#type(iris2) still dataframe
#iris2["species"][57]
pd.set_option('display.max_rows', None) #to print all rows to see all species
iris2

# %%
iris_v_idx = iris.reset_index().set_index(['species'])
irisversicolor = iris_v_idx.loc['versicolor']
irisversicolor[['sepal_length','petal_length']].corr()
# Out:
#               sepal_length  petal_length
# sepal_length      1.000000      0.754049
# petal_length      0.754049      1.000000

# %%
iris_s_idx = iris.reset_index().set_index(['species'])
irisversicolor = iris_s_idx.loc['setosa']
irisversicolor[['sepal_length','petal_length']].corr()
# Out:
#               sepal_length  petal_length
# sepal_length      1.000000      0.267176
# petal_length      0.267176      1.000000

# %%
iris_v2_idx = iris.reset_index().set_index(['species'])
irisversicolor = iris_v2_idx.loc['virginica']
irisversicolor[['sepal_length','petal_length']].corr()
# Out:
#               sepal_length  petal_length
# sepal_length      1.000000      0.864225
# petal_length      0.864225      1.000000

# %%
#FINAL ANSWER = virginica

# %% [markdown]
# 13.  Among the four variables, the two that are most negatively correlated (overall) are `sepal_width` and `petal_length`.  (How do we know this?)  Determine the same thing but for each species separately:  for each species, which two variables have the most negative (or the least positive) correlation?  Again, include calculations to support your answer.

# %%
#supporting evidence for how we know that the most negatively correlated (overall) are sepal_width and petal_length.

iris[['sepal_length','sepal_width']].corr()
# Out:
#               sepal_length  sepal_width
# sepal_length       1.00000     -0.11757
# sepal_width       -0.11757      1.00000

# %%
iris[['sepal_length','petal_length']].corr()
# Out:
#               sepal_length  petal_length
# sepal_length      1.000000      0.871754
# petal_length      0.871754      1.000000

# %%
iris[['sepal_length','petal_width']].corr()
# Out:
#               sepal_length  petal_width
# sepal_length      1.000000     0.817941
# petal_width       0.817941     1.000000

# %%
iris[['sepal_width','petal_length']].corr()
# Out:
#               sepal_width  petal_length
# sepal_width       1.00000      -0.42844
# petal_length     -0.42844       1.00000

# %%
iris[['sepal_width','petal_width']].corr()
# Out:
#              sepal_width  petal_width
# sepal_width     1.000000    -0.366126
# petal_width    -0.366126     1.000000

# %%
iris[['petal_length','petal_width']].corr()
# Out:
#               petal_length  petal_width
# petal_length      1.000000     0.962865
# petal_width       0.962865     1.000000

# %%
#ermmmm we know this because the correlation is the lowest/furthest from 1 at -.42844

# %%
#for versicolor following chunks

iris_v_idx = iris.reset_index().set_index(['species'])
irisversicolor = iris_v_idx.loc['versicolor']
irisversicolor[['sepal_length','petal_length']].corr()
# Out:
#               sepal_length  petal_length
# sepal_length      1.000000      0.754049
# petal_length      0.754049      1.000000

# %%
iris_v_idx = iris.reset_index().set_index(['species'])
irisversicolor = iris_v_idx.loc['versicolor']
irisversicolor[['sepal_length','sepal_width']].corr()
# Out:
#               sepal_length  sepal_width
# sepal_length      1.000000     0.525911
# sepal_width       0.525911     1.000000

# %%
iris_v_idx = iris.reset_index().set_index(['species'])
irisversicolor = iris_v_idx.loc['versicolor']
irisversicolor[['sepal_length','petal_width']].corr()
# Out:
#               sepal_length  petal_width
# sepal_length      1.000000     0.546461
# petal_width       0.546461     1.000000

# %%
iris_v_idx = iris.reset_index().set_index(['species'])
irisversicolor = iris_v_idx.loc['versicolor']
irisversicolor[['sepal_width','petal_length']].corr()
# Out:
#               sepal_width  petal_length
# sepal_width      1.000000      0.560522
# petal_length     0.560522      1.000000

# %%
iris_v_idx = iris.reset_index().set_index(['species'])
irisversicolor = iris_v_idx.loc['versicolor']
irisversicolor[['sepal_width','petal_width']].corr()
# Out:
#              sepal_width  petal_width
# sepal_width     1.000000     0.663999
# petal_width     0.663999     1.000000

# %%
iris_v_idx = iris.reset_index().set_index(['species'])
irisversicolor = iris_v_idx.loc['versicolor']
irisversicolor[['petal_length','petal_width']].corr()
# Out:
#               petal_length  petal_width
# petal_length      1.000000     0.786668
# petal_width       0.786668     1.000000

# %%
#for veriscolor'sepal_length' and 'sepal_width' has the most negative correltion

# %%
#the following is setosa

iris_s_idx = iris.reset_index().set_index(['species'])
irisversicolor = iris_s_idx.loc['setosa']
irisversicolor[['sepal_length','petal_length']].corr()
# Out:
#               sepal_length  petal_length
# sepal_length      1.000000      0.267176
# petal_length      0.267176      1.000000

# %%
iris_v_idx = iris.reset_index().set_index(['species'])
irisversicolor = iris_s_idx.loc['setosa']
irisversicolor[['sepal_length','sepal_width']].corr()
# Out:
#               sepal_length  sepal_width
# sepal_length      1.000000     0.742547
# sepal_width       0.742547     1.000000

# %%
iris_s_idx = iris.reset_index().set_index(['species'])
irisversicolor = iris_s_idx.loc['setosa']
irisversicolor[['sepal_length','petal_width']].corr()
# Out:
#               sepal_length  petal_width
# sepal_length      1.000000     0.278098
# petal_width       0.278098     1.000000

# %%
iris_s_idx = iris.reset_index().set_index(['species'])
irisversicolor = iris_s_idx.loc['setosa']
irisversicolor[['sepal_width','petal_length']].corr()
# Out:
#               sepal_width  petal_length
# sepal_width        1.0000        0.1777
# petal_length       0.1777        1.0000

# %%
iris_s_idx = iris.reset_index().set_index(['species'])
irisversicolor = iris_s_idx.loc['setosa']
irisversicolor[['sepal_width','petal_width']].corr()
# Out:
#              sepal_width  petal_width
# sepal_width     1.000000     0.232752
# petal_width     0.232752     1.000000

# %%
iris_s_idx = iris.reset_index().set_index(['species'])
irisversicolor = iris_s_idx.loc['setosa']
irisversicolor[['petal_length','petal_width']].corr()
# Out:
#               petal_length  petal_width
# petal_length       1.00000      0.33163
# petal_width        0.33163      1.00000

# %%
#for setosa 'sepal_width'and 'petal_length' has the most negative correlation

# %%
iris_v2_idx = iris.reset_index().set_index(['species'])
irisversicolor = iris_v2_idx.loc['virginica']
irisversicolor[['sepal_length','petal_length']].corr()
# Out:
#               sepal_length  petal_length
# sepal_length      1.000000      0.864225
# petal_length      0.864225      1.000000

# %%
iris_v2_idx = iris.reset_index().set_index(['species'])
irisversicolor = iris_v2_idx.loc['virginica']
irisversicolor[['sepal_length','sepal_width']].corr()
# Out:
#               sepal_length  sepal_width
# sepal_length      1.000000     0.457228
# sepal_width       0.457228     1.000000

# %%
iris_v2_idx = iris.reset_index().set_index(['species'])
irisversicolor = iris_v2_idx.loc['virginica']
irisversicolor[['sepal_length','petal_width']].corr()
# Out:
#               sepal_length  petal_width
# sepal_length      1.000000     0.281108
# petal_width       0.281108     1.000000

# %%
iris_v2_idx = iris.reset_index().set_index(['species'])
irisversicolor = iris_v2_idx.loc['virginica']
irisversicolor[['sepal_width','petal_length']].corr()
# Out:
#               sepal_width  petal_length
# sepal_width      1.000000      0.401045
# petal_length     0.401045      1.000000

# %%
iris_v2_idx = iris.reset_index().set_index(['species'])
irisversicolor = iris_v2_idx.loc['virginica']
irisversicolor[['sepal_width','petal_width']].corr()
# Out:
#              sepal_width  petal_width
# sepal_width     1.000000     0.537728
# petal_width     0.537728     1.000000

# %%
iris_v2_idx = iris.reset_index().set_index(['species'])
irisversicolor = iris_v2_idx.loc['virginica']
irisversicolor[['petal_length','petal_width']].corr()
# Out:
#               petal_length  petal_width
# petal_length      1.000000     0.322108
# petal_width       0.322108     1.000000

# %%
# for virginica 'sepal_length' and 'petal_width' has the most negative correlation

# %% [markdown]
# 14.  Once again, the variables `sepal_width` and `petal_length` are negatively correlated.  But for each individual species, these two variables are positively correlated.  How is this possible?  Explain this phenomenon.  Use a data visualization if it helps.

# %% [markdown]
# Simpson's paradox where trend differs among groups individually versus when you combine them and look at aggregate trend or in our speciifc case, the aggregate
# correlation can be negative even if correlations within individual speciies are positive. When looking at the scatter, I think this is because the differences  between cluster of virginica with a 0.401045 correlation and versicolar with a  0.560522, outweigh the difference that we see for the cluster of sertosa with a .1777 correlation.

# %%
iris.plot.scatter('sepal_width', 'petal_length')
# Out:
# <Axes: xlabel='sepal_width', ylabel='petal_length'>
